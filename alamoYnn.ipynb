# %%
#  ___________________________________________________________________________
#
#  Surrogate vs. Implicit: Experiments comparing nonlinear optimization
#  formulations
#
#  Copyright (c) 2023. Triad National Security, LLC. All rights reserved.
#
#  This program was produced under U.S. Government contract 89233218CNA000001
#  for Los Alamos National Laboratory (LANL), which is operated by Triad
#  National Security, LLC for the U.S. Department of Energy/National Nuclear
#  Security Administration. All rights in the program are reserved by Triad
#  National Security, LLC, and the U.S. Department of Energy/National Nuclear
#  Security Administration. The Government is granted for itself and others
#  acting on its behalf a nonexclusive, paid-up, irrevocable worldwide license
#  in this material to reproduce, prepare derivative works, distribute copies
#  to the public, perform publicly and display publicly, and to permit others
#  to do so.
#
#  This software is distributed under the 3-clause BSD license.
#  ___________________________________________________________________________

######## IMPORT PACKAGES ########
import os
import numpy as np
import pandas as pd
from pyomo.common.timing import TicTocTimer
import pyomo.environ as pyo
from pyomo.environ import (
    Constraint,
    Var,
    ConcreteModel,
    Expression,
    Objective,
    TransformationFactory,
    value,
    units as pyunits,
)
from pyomo.network import Arc
from idaes.core import FlowsheetBlock
from idaes.models.properties.modular_properties import GenericParameterBlock
from idaes.core.util.model_statistics import degrees_of_freedom
import idaes.core.util.scaling as iscale

from idaes.models.unit_models import (
    Mixer,
    HeatExchanger,
    PressureChanger,
    Separator,
    Heater,
    Feed,
    Product)
from idaes.core.util.initialization import propagate_state
from idaes.models_extra.power_generation.properties.natural_gas_PR import get_prop
from idaes.core.solvers import get_solver
from idaes.models.unit_models.pressure_changer import ThermodynamicAssumption
from idaes.models.unit_models.heat_exchanger import delta_temperature_underwood_callback
from idaes.core.surrogate.alamopy import AlamoSurrogate
from idaes.core.surrogate.surrogate_block import SurrogateBlock

def build_alamo_atr_flowsheet(m,alamo_surrogate_dict, conversion):
   ########## ADD THERMODYNAMIC PROPERTIES ##########  
    components = ['H2', 'CO', "H2O", 'CO2', 'CH4', "C2H6", "C3H8", "C4H10",'N2', 'O2', 'Ar']
    thermo_props_config_dict = get_prop(components = components)
    m.fs.thermo_params = GenericParameterBlock(**thermo_props_config_dict)

    ########## ADD FEED AND PRODUCT STREAMS ##########  
    m.fs.feed = Feed(property_package = m.fs.thermo_params)
    m.fs.product = Product(property_package = m.fs.thermo_params)
    m.fs.steam_feed = Feed(property_package = m.fs.thermo_params)

    ########## ADD UNIT MODELS ##########  
    m.fs.reformer_recuperator = HeatExchanger(
        delta_temperature_callback = delta_temperature_underwood_callback,
        hot_side_name="shell", # hot fluid enters shell
        cold_side_name="tube", # cold fluid enters tube
        shell = {"property_package": m.fs.thermo_params},
        tube = {"property_package": m.fs.thermo_params})

    m.fs.NG_expander = PressureChanger(
        compressor = False,
        property_package = m.fs.thermo_params,
        thermodynamic_assumption = ThermodynamicAssumption.isentropic)

    m.fs.reformer_bypass = Separator(
        outlet_list = ["reformer_outlet", "bypass_outlet"],
        property_package = m.fs.thermo_params)

    m.fs.air_compressor_s1 = PressureChanger(
        compressor=True,
        property_package=m.fs.thermo_params,
        thermodynamic_assumption=ThermodynamicAssumption.isentropic,
    )

    m.fs.intercooler_s1 = Heater(
        property_package=m.fs.thermo_params, has_pressure_change=True
    )

    m.fs.air_compressor_s2 = PressureChanger(
        compressor=True,
        property_package=m.fs.thermo_params,
        thermodynamic_assumption=ThermodynamicAssumption.isentropic,
    )

    m.fs.intercooler_s2 = Heater(
        property_package=m.fs.thermo_params, has_pressure_change=True
    )

    ########## DEFINE SURROGATE BLOCK FOR THE ATR ##########

    m.fs.reformer = SurrogateBlock() 
    m.fs.reformer.conversion = Var(bounds=(0, 1), units=pyunits.dimensionless) 
    m.fs.reformer.conversion.fix(conversion) # ACHIEVE A CONVERSION OF 0.95 IN ATR

    ########## CREATE OUTLET VARS FOR ATR SURROGATE ##########

    m.fs.reformer.heat_duty = Var(initialize = 43262357) # W
    m.fs.reformer.out_flow_mol = Var(initialize = 3217) # mol/s
    m.fs.reformer.out_temp = Var(initialize = 998.8) # K
    m.fs.reformer.out_H2 = Var(initialize = 0.415311)
    m.fs.reformer.out_CO = Var(initialize = 0.169659)
    m.fs.reformer.out_H2O = Var(initialize = 0.042004)
    m.fs.reformer.out_CO2 = Var(initialize = 0.024803)
    m.fs.reformer.out_CH4 = Var(initialize = 0.021087)
    m.fs.reformer.out_C2H6 = Var(initialize = 0.000000194)
    m.fs.reformer.out_C3H8 = Var(initialize = 0.00000000000705)
    m.fs.reformer.out_C4H10 = Var(initialize = 0.000000000000000241)
    m.fs.reformer.out_N2 = Var(initialize = 0.323243566)
    m.fs.reformer.out_O2 = Var(initialize = 1e-19)
    m.fs.reformer.out_Ar = Var(initialize = 0.003892586)

    # define the inputs to the surrogate models
    inputs = [m.fs.reformer_bypass.reformer_outlet.flow_mol[0], 
                m.fs.reformer_bypass.reformer_outlet.temperature[0], 
                m.fs.steam_feed.flow_mol[0],
                # m.fs.intercooler_s2.outlet.flow_mol[0],
                m.fs.reformer.conversion]

    # define the outputs of the surrogate models
    outputs = [m.fs.reformer.heat_duty, m.fs.reformer.out_flow_mol, m.fs.reformer.out_temp, m.fs.reformer.out_H2,
                m.fs.reformer.out_CO, m.fs.reformer.out_H2O, m.fs.reformer.out_CO2, m.fs.reformer.out_CH4, m.fs.reformer.out_C2H6,
                m.fs.reformer.out_C3H8, m.fs.reformer.out_C4H10, m.fs.reformer.out_N2, m.fs.reformer.out_O2, m.fs.reformer.out_Ar]

    # build the surrogate for the Gibbs Reactor using the JSON file obtained before
    surrogate = AlamoSurrogate.load_from_file(alamo_surrogate_dict)
    m.fs.reformer.build_model(surrogate, input_vars=inputs, output_vars=outputs)

    m.fs.bypass_rejoin = Mixer(
        inlet_list = ["syngas_inlet", "bypass_inlet"],
        property_package = m.fs.thermo_params)


    ########## CONNECT UNIT MODELS UPSTREAM OF SURROGATE REFORMER ##########  

    m.fs.RECUP_COLD_IN = Arc(source=m.fs.feed.outlet, destination=m.fs.reformer_recuperator.tube_inlet)
    m.fs.RECUP_COLD_OUT = Arc(source=m.fs.reformer_recuperator.tube_outlet, destination=m.fs.NG_expander.inlet)
    m.fs.NG_EXPAND_OUT = Arc(source=m.fs.NG_expander.outlet, destination=m.fs.reformer_bypass.inlet)
    m.fs.STAGE_1_OUT = Arc(source=m.fs.air_compressor_s1.outlet, destination=m.fs.intercooler_s1.inlet)
    m.fs.IC_1_OUT = Arc(source=m.fs.intercooler_s1.outlet, destination=m.fs.air_compressor_s2.inlet)
    m.fs.STAGE_2_OUT = Arc(source=m.fs.air_compressor_s2.outlet, destination=m.fs.intercooler_s2.inlet)

    ########## CONNECT OUTPUTS OF SURROGATE TO RECUPERATOR SHELL INLET ##########  

    m.fs.reformer_recuperator.shell_inlet.pressure[0].fix(137895)

    m.fs.reformer_recuperator.shell_inlet.flow_mol[0].set_value(value(m.fs.reformer.out_flow_mol))
    m.fs.reformer_recuperator.shell_inlet.temperature[0].set_value(value(m.fs.reformer.out_temp))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2'].set_value(value(m.fs.reformer.out_H2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO'].set_value(value(m.fs.reformer.out_CO))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2O'].set_value(value(m.fs.reformer.out_H2O))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO2'].set_value(value(m.fs.reformer.out_CO2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CH4'].set_value(value(m.fs.reformer.out_CH4))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C2H6'].set_value(value(m.fs.reformer.out_C2H6))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C3H8'].set_value(value(m.fs.reformer.out_C3H8))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C4H10'].set_value(value(m.fs.reformer.out_C4H10))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'N2'].set_value(value(m.fs.reformer.out_N2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'O2'].set_value(value(m.fs.reformer.out_O2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'Ar'].set_value(value(m.fs.reformer.out_Ar))

    ########## CONNECT UNIT MODELS DOWNSTREAM OF SURROGATE REFORMER ##########  

    m.fs.RECUP_HOT_OUT = Arc(source=m.fs.reformer_recuperator.shell_outlet, destination=m.fs.bypass_rejoin.syngas_inlet)
    m.fs.REF_BYPASS = Arc(source=m.fs.reformer_bypass.bypass_outlet, destination=m.fs.bypass_rejoin.bypass_inlet)
    m.fs.PRODUCT = Arc(source=m.fs.bypass_rejoin.outlet, destination=m.fs.product.inlet)

    ########## EXPAND ARCS ##########  

    pyo.TransformationFactory("network.expand_arcs").apply_to(m.fs)

def set_alamo_atr_flowsheet_inputs(m,P):
    # natural gas feed conditions

    m.fs.feed.outlet.flow_mol.fix(1161.9)  # mol/s
    m.fs.feed.outlet.temperature.fix(288.15)  # K
    m.fs.feed.outlet.pressure.fix(P) # Pa
    m.fs.feed.outlet.mole_frac_comp[0, 'CH4'].fix(0.931)
    m.fs.feed.outlet.mole_frac_comp[0, 'C2H6'].fix(0.032)
    m.fs.feed.outlet.mole_frac_comp[0, 'C3H8'].fix(0.007)
    m.fs.feed.outlet.mole_frac_comp[0, 'C4H10'].fix(0.004)
    m.fs.feed.outlet.mole_frac_comp[0, 'CO'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'CO2'].fix(0.01)
    m.fs.feed.outlet.mole_frac_comp[0, 'H2'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'H2O'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'N2'].fix(0.016)
    m.fs.feed.outlet.mole_frac_comp[0, 'O2'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'Ar'].fix(1e-5)

    # recuperator conditions

    m.fs.reformer_recuperator.area.fix(4190) # m2
    m.fs.reformer_recuperator.overall_heat_transfer_coefficient.fix(80) # W/m2K # it was 80e-3 # potential bug

    # natural gas expander conditions

    m.fs.NG_expander.outlet.pressure.fix(203396) # Pa
    m.fs.NG_expander.efficiency_isentropic.fix(0.9)

    # air conditions

    m.fs.air_compressor_s1.inlet.flow_mol.fix(1332.9)  # mol/s
    m.fs.air_compressor_s1.inlet.temperature.fix(288.15)  # K
    m.fs.air_compressor_s1.inlet.pressure.fix(101353)  # Pa
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "CO2"].fix(0.0003)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "H2O"].fix(0.0104)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "N2"].fix(0.7722)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "O2"].fix(0.2077)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "Ar"].fix(0.00939)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "CH4"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "C2H6"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "C3H8"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "C4H10"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "CO"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "H2"].fix(1e-6)

    # air compressors and intercoolers

    m.fs.air_compressor_s1.outlet.pressure.fix(144790)  # Pa
    m.fs.air_compressor_s1.efficiency_isentropic.fix(0.84)

    m.fs.intercooler_s1.outlet.temperature.fix(310.93)  # K
    m.fs.intercooler_s1.outlet.pressure.fix(141343)  # Pa equivalent to a dP of -0.5 psi

    m.fs.air_compressor_s2.outlet.pressure.fix(206843)  # Pa
    m.fs.air_compressor_s2.efficiency_isentropic.fix(0.84)

    m.fs.intercooler_s2.outlet.temperature.fix(310.93)  # K
    m.fs.intercooler_s2.outlet.pressure.fix(203396)  # Pa equivalent to a dP of -0.5 psi

    # steam conditions

    m.fs.steam_feed.flow_mol.fix(464.77) # mol/s, this value will be unfixed. It's just to initialize.
    m.fs.steam_feed.temperature.fix(422) # K
    m.fs.steam_feed.pressure.fix(203396)  # Pa
    m.fs.steam_feed.mole_frac_comp[0, 'H2O'].fix(0.9999)
    m.fs.steam_feed.mole_frac_comp[0, 'CO2'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'N2'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'O2'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'Ar'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'CH4'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'C2H6'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'C3H8'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'C4H10'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'CO'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'H2'].fix(1e-6)
    
def initialize_alamo_atr_flowsheet(m):
    ########## INITIALIZE AND PROPAGATE STATES ##########
    m.fs.reformer_recuperator.initialize()
    m.fs.bypass_rejoin.initialize()
    m.fs.product.initialize()
    m.fs.feed.initialize()
    m.fs.NG_expander.initialize()
    m.fs.air_compressor_s1.initialize()
    m.fs.intercooler_s1.initialize()
    m.fs.air_compressor_s2.initialize()
    m.fs.intercooler_s2.initialize()
    m.fs.reformer_bypass.inlet.flow_mol.fix(1161.9)
    m.fs.reformer_bypass.inlet.temperature.fix(700)  # K
    m.fs.reformer_bypass.initialize()

def make_simulation_model(X, P):
    m = pyo.ConcreteModel(name="ATR_Flowsheet")
    m.fs = FlowsheetBlock(dynamic=False)
    # dirname = os.path.dirname(__file__)
    # basename = "alamo_surrogate_atr.json"
    # fname = os.path.join(dirname, basename)
    build_alamo_atr_flowsheet(m, alamo_surrogate_dict = "C:/Users/sbugo/surr-vs-imp/surrogate-vs-implicit/svi/auto_thermal_reformer/alamo_surrogate_atr.json", conversion = X)
    set_alamo_atr_flowsheet_inputs(m, P)
    initialize_alamo_atr_flowsheet(m)
    m.fs.reformer_bypass.inlet.temperature.unfix()
    m.fs.reformer_bypass.inlet.flow_mol.unfix()
    return m

df = {'X':[], 'P':[], 'Termination':[], 'Time':[], 'Objective':[], 'Steam':[], 'Bypass Frac': [], 'CH4 Feed':[]}

if __name__ == "__main__":
    """
    The optimization problem to solve is the following:
    Maximize H2 composition in the product stream such that its minimum flow is 3500 mol/s, 
    its maximum N2 concentration is 0.3, the maximum reformer outlet temperature is 1200 K and 
    the maximum product temperature is 650 K.  
    """
    for X in [0.90,0.91,0.92,0.93,0.94,0.95,0.96,0.97]:
        for P in np.arange(1447379,1947379,70000):
            try: 
                m = make_simulation_model(X,P)

                ####### OBJECTIVE IS TO MAXIMIZE H2 COMPOSITION IN PRODUCT STREAM #######
                m.fs.obj = pyo.Objective(expr = m.fs.product.mole_frac_comp[0, 'H2'], sense = pyo.maximize)

                ####### CONSTRAINTS #######

                # Link outputs of ALAMO to inputs of reformer_recuperator 
                @m.Constraint()
                def link_T(m):
                    return m.fs.reformer_recuperator.shell_inlet.flow_mol[0] == m.fs.reformer.out_flow_mol

                @m.Constraint()
                def link_F(m):
                    return m.fs.reformer_recuperator.shell_inlet.temperature[0] == m.fs.reformer.out_temp

                @m.Constraint()
                def link_H2(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2'] == m.fs.reformer.out_H2

                @m.Constraint()
                def link_CO(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO'] == m.fs.reformer.out_CO

                @m.Constraint()
                def link_H2O(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2O'] == m.fs.reformer.out_H2O

                @m.Constraint()
                def link_CO2(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO2'] == m.fs.reformer.out_CO2

                @m.Constraint()
                def link_CH4(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CH4'] == m.fs.reformer.out_CH4

                @m.Constraint()
                def link_C2H6(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C2H6'] == m.fs.reformer.out_C2H6

                @m.Constraint()
                def link_C3H8(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C3H8'] == m.fs.reformer.out_C3H8

                @m.Constraint()
                def link_C4H10(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C4H10'] == m.fs.reformer.out_C4H10

                @m.Constraint()
                def link_N2(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'N2'] == m.fs.reformer.out_N2

                @m.Constraint()
                def link_O2(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'O2'] == m.fs.reformer.out_O2

                @m.Constraint()
                def link_Ar(m):
                    return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'Ar'] == m.fs.reformer.out_Ar

                # MINIMUM PRODUCT FLOW OF 3500 mol/s IN PRODUCT STREAM
                @m.Constraint()
                def min_product_flow_mol(m):
                    return m.fs.product.flow_mol[0] >= 3500

                # MAXIMUM N2 COMPOSITION OF 0.3 IN PRODUCT STREAM
                @m.Constraint()
                def max_product_N2_comp(m):
                    return m.fs.product.mole_frac_comp[0, 'N2'] <= 0.3

                # MAXIMUM REFORMER OUTLET TEMPERATURE OF 1200 K
                @m.Constraint()
                def max_reformer_outlet_temp(m):
                    return m.fs.reformer.out_temp <= 1200

                # MAXIMUM PRODUCT OUTLET TEMPERATURE OF 650 K
                @m.Constraint()
                def max_product_temp(m):
                    return m.fs.product.temperature[0] <= 650

                m.fs.feed.outlet.flow_mol[0].setlb(1120)
                m.fs.feed.outlet.flow_mol[0].setub(1250)
                # Unfix D.O.F. If you unfix these variables, inlet temperature, flow and composition
                # to the Gibbs reactor will have to be determined by the optimization problem.
                m.fs.reformer_bypass.split_fraction[0, "bypass_outlet"].unfix()
                m.fs.feed.outlet.flow_mol.unfix()
                m.fs.steam_feed.flow_mol.unfix() 

                solver = get_solver()
                solver.options = {
                    "tol": 1e-7,
                    "max_iter": 300
                }
                timer = TicTocTimer()
                timer.tic('starting timer')
                results = solver.solve(m, tee=True)
                dT = timer.toc('end')
                df[list(df.keys())[0]].append(X)
                df[list(df.keys())[1]].append(P)
                df[list(df.keys())[2]].append(results.solver.termination_condition)
                df[list(df.keys())[3]].append(dT)
                df[list(df.keys())[4]].append(value(m.fs.product.mole_frac_comp[0, 'H2']))
                df[list(df.keys())[5]].append(value(m.fs.steam_feed.flow_mol[0]))
                df[list(df.keys())[6]].append(value(m.fs.reformer_bypass.split_fraction[0, 'bypass_outlet']))
                df[list(df.keys())[7]].append(value(m.fs.feed.outlet.flow_mol[0]))
            except ValueError:
                df[list(df.keys())[0]].append(X)
                df[list(df.keys())[1]].append(P)
                df[list(df.keys())[2]].append("ValueError")
                df[list(df.keys())[3]].append(999)
                df[list(df.keys())[4]].append(999)
                df[list(df.keys())[5]].append(999)
                df[list(df.keys())[6]].append(999)
                df[list(df.keys())[7]].append(value(m.fs.feed.outlet.flow_mol[0]))
                continue
# Out:
# WARNING (W1002): Setting Var 'fs.steam_feed.properties[0.0].flow_mol' to a
# numeric value `464.77` outside the bounds (200.0522428, 349.8636404).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:55:12 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Starting initialization
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Starting initialization
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.hot_side: Initialization Complete
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Starting initialization
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Starting initialization
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:13 [INFO] idaes.init.fs.reformer_recuperator.cold_side: Initialization Complete
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.reformer_recuperator: Initialization Completed, optimal - Optimal Solution Found
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Starting initialization
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:14 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:15 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:16 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:17 [INFO] idaes.init.fs.intercooler_s1.control_volume: Initialization Complete
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.intercooler_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Starting initialization
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:18 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.air_compressor_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.intercooler_s2.control_volume: Initialization Complete
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.intercooler_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Starting initialization
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Property initialization: optimal - Optimal Solution Found.
# WARNING (W1002): Setting Var
# 'fs.reformer_bypass.reformer_outlet_state[0.0].flow_mol' to a numeric value
# `580.95` outside the bounds (601.206081, 899.7018541).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:55:19 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Starting initialization
# 2023-10-03 16:55:20 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:20 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:20 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Starting initialization
# 2023-10-03 16:55:20 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:20 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55
07e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50 -4.0357242e-01 1.00e+01 1.32e+01  -5.7 1.01e+05    -  9.95e-01 1.00e+00h  1
#   51 -4.0358552e-01 1.49e-01 3.26e-04  -5.7 1.50e+04    -  1.00e+00 1.00e+00h  1
#   52 -4.0358551e-01 1.32e-05 2.82e-11  -5.7 3.00e+01    -  1.00e+00 1.00e+00h  1
#   53 -4.0359099e-01 1.69e-02 1.65e+00  -8.0 5.19e+03    -  1.00e+00 9.91e-01h  1
#   54 -4.0359103e-01 4.78e-06 4.97e-07  -8.0 4.46e+01    -  1.00e+00 1.00e+00f  1
#   55 -4.0359103e-01 2.98e-08 9.10e-14  -8.0 3.88e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 55
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.0359102651919676e-01   -4.0359102651919676e-01
# Dual infeasibility......:   9.1012721601953747e-14    9.1012721601953747e-14
# Constraint violation....:   2.3283064365386963e-10    2.9802322387695312e-08
# Complementarity.........:   9.0909090966572764e-09    9.0909090966572764e-09
# Overall NLP error.......:   9.0909090966572764e-09    2.9802322387695312e-08
#
#
# Number of objective function evaluations             = 102
# Number of objective gradient evaluations             = 51
# Number of equality constraint evaluations            = 102
# Number of inequality constraint evaluations          = 102
# Number of equality constraint Jacobian evaluations   = 57
# Number of inequality constraint Jacobian evaluations = 57
# Number of Lagrangian Hessian evaluations             = 55
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.230
# Total CPU secs in NLP function evaluations           =      0.437
#
# EXIT: Optimal Solution Found.
# [+   1.39] end
# WARNING (W1002): Setting Var 'fs.steam_feed.properties[0.0].flow_mol' to a
# numeric value `464.77` outside the bounds (200.0522428, 349.8636404).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Starting initialization
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Starting initialization
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.hot_side: Initialization Complete
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Starting initialization
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:23 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Starting initialization
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.reformer_recuperator.cold_side: Initialization Complete
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.reformer_recuperator: Initialization Completed, optimal - Optimal Solution Found
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Starting initialization
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:24 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:25 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:26 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 16:55:27 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:27 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:27 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:27 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:27 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:27 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.intercooler_s1.control_volume: Initialization Complete
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.intercooler_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Starting initialization
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:28 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.air_compressor_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.intercooler_s2.control_volume: Initialization Complete
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.intercooler_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:29 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Starting initialization
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Property initialization: optimal - Optimal Solution Found.
# WARNING (W1002): Setting Var
# 'fs.reformer_bypass.reformer_outlet_state[0.0].flow_mol' to a numeric value
# `580.95` outside the bounds (601.206081, 899.7018541).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Starting initialization
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Starting initialization
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:30 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55
-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 53
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.0480443401498245e-01   -4.0480443401498245e-01
# Dual infeasibility......:   9.1012721601953747e-14    9.1012721601953747e-14
# Constraint violation....:   2.3283064365386963e-10    4.4703483581542969e-08
# Complementarity.........:   9.0909090909090958e-09    9.0909090909090958e-09
# Overall NLP error.......:   9.0909090909090958e-09    4.4703483581542969e-08
#
#
# Number of objective function evaluations             = 90
# Number of objective gradient evaluations             = 49
# Number of equality constraint evaluations            = 90
# Number of inequality constraint evaluations          = 90
# Number of equality constraint Jacobian evaluations   = 55
# Number of inequality constraint Jacobian evaluations = 55
# Number of Lagrangian Hessian evaluations             = 53
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.215
# Total CPU secs in NLP function evaluations           =      0.437
#
# EXIT: Optimal Solution Found.
# [+   1.46] end
# WARNING (W1002): Setting Var 'fs.steam_feed.properties[0.0].flow_mol' to a
# numeric value `464.77` outside the bounds (200.0522428, 349.8636404).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:55:33 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Starting initialization
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Starting initialization
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.hot_side: Initialization Complete
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Starting initialization
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Starting initialization
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:34 [INFO] idaes.init.fs.reformer_recuperator.cold_side: Initialization Complete
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.reformer_recuperator: Initialization Completed, optimal - Optimal Solution Found
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Starting initialization
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:35 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:36 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 16:55:37 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:37 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:37 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:37 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:38 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:39 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:39 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:39 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:39 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:39 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:39 [INFO] idaes.init.fs.intercooler_s1.control_volume: Initialization Complete
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.intercooler_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Starting initialization
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:40 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:41 [INFO] idaes.init.fs.air_compressor_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:41 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:55:41 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:41 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:55:41 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:41 [INFO] idaes.init.fs.intercooler_s2.control_volume: Initialization Complete
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.intercooler_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Starting initialization
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Property initialization: optimal - Optimal Solution Found.
# WARNING (W1002): Setting Var
# 'fs.reformer_bypass.reformer_outlet_state[0.0].flow_mol' to a numeric value
# `580.95` outside the bounds (601.206081, 899.7018541).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Starting initialization
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Starting initialization
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:55:42 [INFO] idaes.init.fs.reformer_bypass: Initialization Step 2 Complete: optimal - Optimal Solution Found
# [    0.00] starting timer
# Ipopt 3.13.2: tol=1e-07
# max_iter=300
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2327
# Number of nonzeros in inequality constraint Jacobian.:        4
# Number of nonzeros in Lagrangian Hessian.............:     3445
#
# Total number of variables............................:      758
#                      variables with only lower bounds:       26
#                 variables with lower and upper bounds:      694
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      755
# Total number of inequality constraints...............:        4
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        3
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -9.0909091e-02 1.80e+07 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -1.1373722e-01 1.54e+07 1.23e+03  -1.0 4.07e+08    -  5.15e-02 1.18e-01h  1
#    2 -1.1623817e-01 1.53e+07 1.23e+03  -1.0 3.30e+08    -  1.23e-01 8.07e-03h  1
#    3 -1.4446978e-01 1.42e+07 2.77e+03  -1.0 4.79e+08    -  2.65e-02 7.10e-02h  1
#    4 -1.4571989e-01 1.41e+07 2.86e+03  -1.0 1.01e+08    -  8.30e-04 9.74e-03h  1
#    5 -1.4613374e-01 1.40e+07 2.87e+03  -1.0 9.68e+07    -  3.27e-02 3.74e-03h  1
#    6 -1.4613946e-01 1.40e+07 1.06e+04  -1.0 9.60e+07    -  1.29e-02 4.67e-05h  1
#    7 -1.4835856e-01 1.38e+07 6.70e+03  -1.0 9.59e+07    -  2.76e-03 1.28e-02h  1
#    8 -1.4838393e-01 1.38e+07 2.61e+05  -1.0 9.29e+07    -  1.89e-02 1.49e-04h  1
#    9r-1.4838393e-01 1.38e+07 9.99e+02   6.1 0.00e+00    -  0.00e+00 4.26e-07R  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r-2.1226379e-01 7.42e+08 3.50e+03   6.1 2.77e+06    -  8.78e-07 1.07e-05f  1
#   11r-2.6623450e-01 7.11e+08 1.52e+04   6.1 4.12e+05    -  1.62e-04 1.51e-05f  1
# ...
# 2023-10-03 17:07:41 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:41 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 17:07:41 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:41 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 17:07:41 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:41 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:42 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:43 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 17:07:44 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.intercooler_s1.control_volume: Initialization Complete
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.intercooler_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:45 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Starting initialization
# 2023-10-03 17:07:46 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:46 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:46 [INFO] idaes.init.fs.air_compressor_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 17:07:46 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 17:07:46 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:46 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.intercooler_s2.control_volume: Initialization Complete
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.intercooler_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Starting initialization
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Property initialization: optimal - Optimal Solution Found.
# WARNING (W1002): Setting Var
# 'fs.reformer_bypass.reformer_outlet_state[0.0].flow_mol' to a numeric value
# `580.95` outside the bounds (601.206081, 899.7018541).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Starting initialization
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:47 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Starting initialization
# 2023-10-03 17:07:48 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:48 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 17:07:48 [INFO] idaes.init.fs.reformer_bypass: Initialization Step 2 Complete: optimal - Optimal Solution Found
# [    0.00] starting timer
# Ipopt 3.13.2: tol=1e-07
# max_iter=300
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2327
# Number of nonzeros in inequality constraint Jacobian.:        4
# Number of nonzeros in Lagrangian Hessian.............:     3445
#
# Total number of variables............................:      758
#                      variables with only lower bounds:       26
#                 variables with lower and upper bounds:      694
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      755
# Total number of inequality constraints...............:        4
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        3
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -9.0909091e-02 3.68e+07 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -1.1101193e-01 3.28e+07 1.05e+03  -1.0 5.02e+08    -  4.20e-02 9.76e-02h  1
#    2 -1.1325363e-01 3.26e+07 1.05e+03  -1.0 4.02e+08    -  1.02e-01 6.34e-03h  1
#    3 -1.4225544e-01 3.06e+07 3.17e+03  -1.0 6.04e+08    -  9.31e-03 6.14e-02h  1
#    4 -1.4322543e-01 3.04e+07 3.23e+03  -1.0 1.30e+08    -  1.73e-03 6.65e-03h  1
#    5 -1.4330776e-01 3.03e+07 3.23e+03  -1.0 1.23e+08    -  7.96e-02 6.85e-04h  1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.317
# Total CPU secs in NLP function evaluations           =      0.525
#
# EXIT: Optimal Solution Found.
# [+   1.70] end

# %%
df = pd.DataFrame(df)
df.to_csv("ALAMODATA.csv")

# %%
df = pd.DataFrame(df)
df.to_csv("alamoYnn.csv")

# %%
#  ___________________________________________________________________________
#
#  Surrogate vs. Implicit: Experiments comparing nonlinear optimization
#  formulations
#
#  Copyright (c) 2023. Triad National Security, LLC. All rights reserved.
#
#  This program was produced under U.S. Government contract 89233218CNA000001
#  for Los Alamos National Laboratory (LANL), which is operated by Triad
#  National Security, LLC for the U.S. Department of Energy/National Nuclear
#  Security Administration. All rights in the program are reserved by Triad
#  National Security, LLC, and the U.S. Department of Energy/National Nuclear
#  Security Administration. The Government is granted for itself and others
#  acting on its behalf a nonexclusive, paid-up, irrevocable worldwide license
#  in this material to reproduce, prepare derivative works, distribute copies
#  to the public, perform publicly and display publicly, and to permit others
#  to do so.
#
#  This software is distributed under the 3-clause BSD license.
#  ___________________________________________________________________________

######## IMPORT PACKAGES ########
import os
import numpy as np
import pandas as pd
import pyomo.environ as pyo
from pyomo.common.timing import TicTocTimer
from pyomo.environ import (
    Constraint,
    Var,
    ConcreteModel,
    Expression,
    Objective,
    TransformationFactory,
    value,
    units as pyunits,
)
from pyomo.network import Arc
from idaes.core import FlowsheetBlock
from idaes.models.properties.modular_properties import GenericParameterBlock
from idaes.core.util.model_statistics import degrees_of_freedom
import idaes.core.util.scaling as iscale

from idaes.models.unit_models import (
    Mixer,
    HeatExchanger,
    PressureChanger,
    Separator,
    Heater,
    Feed,
    Product)
from idaes.core.util.initialization import propagate_state
from idaes.models_extra.power_generation.properties.natural_gas_PR import get_prop
from idaes.core.solvers import get_solver
from idaes.models.unit_models.pressure_changer import ThermodynamicAssumption
from idaes.models.unit_models.heat_exchanger import delta_temperature_underwood_callback
from idaes.core.surrogate.surrogate_block import SurrogateBlock
from idaes.core.surrogate.sampling.data_utils import split_training_validation
from idaes.core.surrogate.sampling.scaling import OffsetScaler
from idaes.core.surrogate.keras_surrogate import (
    KerasSurrogate,
    save_keras_json_hd5,
    load_keras_json_hd5,
)

def build_nn_atr_flowsheet(m, conversion):
   ########## ADD THERMODYNAMIC PROPERTIES ##########  
    components = ['H2', 'CO', "H2O", 'CO2', 'CH4', "C2H6", "C3H8", "C4H10",'N2', 'O2', 'Ar']
    thermo_props_config_dict = get_prop(components = components)
    m.fs.thermo_params = GenericParameterBlock(**thermo_props_config_dict)

    ########## ADD FEED AND PRODUCT STREAMS ##########  
    m.fs.feed = Feed(property_package = m.fs.thermo_params)
    m.fs.product = Product(property_package = m.fs.thermo_params)
    m.fs.steam_feed = Feed(property_package = m.fs.thermo_params)

    ########## ADD UNIT MODELS ##########  
    m.fs.reformer_recuperator = HeatExchanger(
        delta_temperature_callback = delta_temperature_underwood_callback,
        hot_side_name="shell", # hot fluid enters shell
        cold_side_name="tube", # cold fluid enters tube
        shell = {"property_package": m.fs.thermo_params},
        tube = {"property_package": m.fs.thermo_params})

    m.fs.NG_expander = PressureChanger(
        compressor = False,
        property_package = m.fs.thermo_params,
        thermodynamic_assumption = ThermodynamicAssumption.isentropic)

    m.fs.reformer_bypass = Separator(
        outlet_list = ["reformer_outlet", "bypass_outlet"],
        property_package = m.fs.thermo_params)
    

    m.fs.air_compressor_s1 = PressureChanger(
        compressor=True,
        property_package=m.fs.thermo_params,
        thermodynamic_assumption=ThermodynamicAssumption.isentropic,
    )

    m.fs.intercooler_s1 = Heater(
        property_package=m.fs.thermo_params, has_pressure_change=True
    )

    m.fs.air_compressor_s2 = PressureChanger(
        compressor=True,
        property_package=m.fs.thermo_params,
        thermodynamic_assumption=ThermodynamicAssumption.isentropic,
    )

    m.fs.intercooler_s2 = Heater(
        property_package=m.fs.thermo_params, has_pressure_change=True
    )

    ########## DEFINE SURROGATE BLOCK FOR THE ATR ##########

    m.fs.reformer = SurrogateBlock()
    m.fs.reformer.conversion = Var(bounds=(0, 1), units=pyunits.dimensionless) 
    m.fs.reformer.conversion.fix(conversion) # ACHIEVE A CONVERSION OF 0.95 IN ATR

    ########## CREATE OUTLET VARS FOR ATR SURROGATE ##########

    m.fs.reformer.heat_duty = Var(initialize = 43262357) # W
    m.fs.reformer.out_flow_mol = Var(initialize = 3217) # mol/s
    m.fs.reformer.out_temp = Var(initialize = 998.8) # K
    m.fs.reformer.out_H2 = Var(initialize = 0.415311)
    m.fs.reformer.out_CO = Var(initialize = 0.169659)
    m.fs.reformer.out_H2O = Var(initialize = 0.042004)
    m.fs.reformer.out_CO2 = Var(initialize = 0.024803)
    m.fs.reformer.out_CH4 = Var(initialize = 0.021087)
    m.fs.reformer.out_C2H6 = Var(initialize = 0.000000194)
    m.fs.reformer.out_C3H8 = Var(initialize = 0.00000000000705)
    m.fs.reformer.out_C4H10 = Var(initialize = 0.000000000000000241)
    m.fs.reformer.out_N2 = Var(initialize = 0.323243566)
    m.fs.reformer.out_O2 = Var(initialize = 1e-19)
    m.fs.reformer.out_Ar = Var(initialize = 0.003892586)

    # define the inputs to the surrogate models
    inputs = [m.fs.reformer_bypass.reformer_outlet.flow_mol[0], 
                m.fs.reformer_bypass.reformer_outlet.temperature[0], 
                m.fs.steam_feed.flow_mol[0],
                m.fs.reformer.conversion]

    # define the outputs of the surrogate models. remove O2, C2H6, C3H8, C4H10 
    # because they were not part of the NN training.
    outputs = [m.fs.reformer.heat_duty, m.fs.reformer.out_flow_mol, m.fs.reformer.out_temp, m.fs.reformer.out_H2,
                m.fs.reformer.out_CO, m.fs.reformer.out_H2O, m.fs.reformer.out_CO2, m.fs.reformer.out_CH4,
                m.fs.reformer.out_N2, m.fs.reformer.out_Ar]

    # build the surrogate for the Gibbs Reactor using the best keras model obtained
    keras_surrogate = KerasSurrogate.load_from_folder("keras_surrogate")
    m.fs.reformer.build_model(
    keras_surrogate,
    formulation=KerasSurrogate.Formulation.FULL_SPACE,
    input_vars=inputs,
    output_vars=outputs,
    )

    m.fs.bypass_rejoin = Mixer(
        inlet_list = ["syngas_inlet", "bypass_inlet"],
        property_package = m.fs.thermo_params)


    ########## CONNECT UNIT MODELS UPSTREAM OF SURROGATE REFORMER ##########  

    m.fs.RECUP_COLD_IN = Arc(source=m.fs.feed.outlet, destination=m.fs.reformer_recuperator.tube_inlet)
    m.fs.RECUP_COLD_OUT = Arc(source=m.fs.reformer_recuperator.tube_outlet, destination=m.fs.NG_expander.inlet)
    m.fs.NG_EXPAND_OUT = Arc(source=m.fs.NG_expander.outlet, destination=m.fs.reformer_bypass.inlet)
    m.fs.STAGE_1_OUT = Arc(source=m.fs.air_compressor_s1.outlet, destination=m.fs.intercooler_s1.inlet)
    m.fs.IC_1_OUT = Arc(source=m.fs.intercooler_s1.outlet, destination=m.fs.air_compressor_s2.inlet)
    m.fs.STAGE_2_OUT = Arc(source=m.fs.air_compressor_s2.outlet, destination=m.fs.intercooler_s2.inlet)

    ########## CONNECT OUTPUTS OF SURROGATE TO RECUPERATOR SHELL INLET ##########  

    m.fs.reformer_recuperator.shell_inlet.pressure[0].fix(137895)

    m.fs.reformer_recuperator.shell_inlet.flow_mol[0].set_value(value(m.fs.reformer.out_flow_mol))
    m.fs.reformer_recuperator.shell_inlet.temperature[0].set_value(value(m.fs.reformer.out_temp))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2'].set_value(value(m.fs.reformer.out_H2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO'].set_value(value(m.fs.reformer.out_CO))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2O'].set_value(value(m.fs.reformer.out_H2O))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO2'].set_value(value(m.fs.reformer.out_CO2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CH4'].set_value(value(m.fs.reformer.out_CH4))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C2H6'].set_value(value(m.fs.reformer.out_C2H6))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C3H8'].set_value(value(m.fs.reformer.out_C3H8))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C4H10'].set_value(value(m.fs.reformer.out_C4H10))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'N2'].set_value(value(m.fs.reformer.out_N2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'O2'].set_value(value(m.fs.reformer.out_O2))
    m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'Ar'].set_value(value(m.fs.reformer.out_Ar))

    ########## CONNECT UNIT MODELS DOWNSTREAM OF SURROGATE REFORMER ##########  

    m.fs.RECUP_HOT_OUT = Arc(source=m.fs.reformer_recuperator.shell_outlet, destination=m.fs.bypass_rejoin.syngas_inlet)
    m.fs.REF_BYPASS = Arc(source=m.fs.reformer_bypass.bypass_outlet, destination=m.fs.bypass_rejoin.bypass_inlet)
    m.fs.PRODUCT = Arc(source=m.fs.bypass_rejoin.outlet, destination=m.fs.product.inlet)

    ########## EXPAND ARCS ##########  

    pyo.TransformationFactory("network.expand_arcs").apply_to(m.fs)

def set_nn_atr_flowsheet_inputs(m,P):
    # natural gas feed conditions

    m.fs.feed.outlet.flow_mol.fix(1161.9)  # mol/s
    m.fs.feed.outlet.temperature.fix(288.15)  # K
    m.fs.feed.outlet.pressure.fix(P) # Pa
    m.fs.feed.outlet.mole_frac_comp[0, 'CH4'].fix(0.931)
    m.fs.feed.outlet.mole_frac_comp[0, 'C2H6'].fix(0.032)
    m.fs.feed.outlet.mole_frac_comp[0, 'C3H8'].fix(0.007)
    m.fs.feed.outlet.mole_frac_comp[0, 'C4H10'].fix(0.004)
    m.fs.feed.outlet.mole_frac_comp[0, 'CO'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'CO2'].fix(0.01)
    m.fs.feed.outlet.mole_frac_comp[0, 'H2'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'H2O'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'N2'].fix(0.016)
    m.fs.feed.outlet.mole_frac_comp[0, 'O2'].fix(1e-5)
    m.fs.feed.outlet.mole_frac_comp[0, 'Ar'].fix(1e-5)

    # recuperator conditions

    m.fs.reformer_recuperator.area.fix(4190) # m2
    m.fs.reformer_recuperator.overall_heat_transfer_coefficient.fix(80) # W/m2K # it was 80e-3 # potential bug

    # natural gas expander conditions

    m.fs.NG_expander.outlet.pressure.fix(203396) # Pa
    m.fs.NG_expander.efficiency_isentropic.fix(0.9)

    # air conditions

    m.fs.air_compressor_s1.inlet.flow_mol.fix(1332.9)  # mol/s
    m.fs.air_compressor_s1.inlet.temperature.fix(288.15)  # K
    m.fs.air_compressor_s1.inlet.pressure.fix(101353)  # Pa
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "CO2"].fix(0.0003)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "H2O"].fix(0.0104)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "N2"].fix(0.7722)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "O2"].fix(0.2077)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "Ar"].fix(0.00939)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "CH4"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "C2H6"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "C3H8"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "C4H10"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "CO"].fix(1e-6)
    m.fs.air_compressor_s1.inlet.mole_frac_comp[0, "H2"].fix(1e-6)

    # air compressors and intercoolers

    m.fs.air_compressor_s1.outlet.pressure.fix(144790)  # Pa
    m.fs.air_compressor_s1.efficiency_isentropic.fix(0.84)

    m.fs.intercooler_s1.outlet.temperature.fix(310.93)  # K
    m.fs.intercooler_s1.outlet.pressure.fix(141343)  # Pa equivalent to a dP of -0.5 psi

    m.fs.air_compressor_s2.outlet.pressure.fix(206843)  # Pa
    m.fs.air_compressor_s2.efficiency_isentropic.fix(0.84)

    m.fs.intercooler_s2.outlet.temperature.fix(310.93)  # K
    m.fs.intercooler_s2.outlet.pressure.fix(203396)  # Pa equivalent to a dP of -0.5 psi

    # steam conditions

    m.fs.steam_feed.flow_mol.fix(464.77) # mol/s, this value will be unfixed. It's just to initialize.
    m.fs.steam_feed.temperature.fix(422) # K
    m.fs.steam_feed.pressure.fix(203396)  # Pa
    m.fs.steam_feed.mole_frac_comp[0, 'H2O'].fix(0.9999)
    m.fs.steam_feed.mole_frac_comp[0, 'CO2'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'N2'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'O2'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'Ar'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'CH4'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'C2H6'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'C3H8'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'C4H10'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'CO'].fix(1e-6)
    m.fs.steam_feed.mole_frac_comp[0, 'H2'].fix(1e-6)

def initialize_nn_atr_flowsheet(m):
    ########## INITIALIZE AND PROPAGATE STATES ##########
    m.fs.reformer_recuperator.initialize()
    m.fs.bypass_rejoin.initialize()
    m.fs.product.initialize()
    m.fs.feed.initialize()
    m.fs.NG_expander.initialize()
    m.fs.air_compressor_s1.initialize()
    m.fs.intercooler_s1.initialize()
    m.fs.air_compressor_s2.initialize()
    m.fs.intercooler_s2.initialize()
    m.fs.reformer_bypass.inlet.flow_mol.fix(1161.9)
    m.fs.reformer_bypass.inlet.temperature.fix(700)
    m.fs.reformer_bypass.initialize()

def make_optimization_model(m):
    """
    The optimization problem to solve is the following:

    Maximize H2 composition in the product stream such that its minimum flow is 3500 mol/s,
    its maximum N2 concentration is 0.3, the maximum reformer outlet temperature is 1200 K and
    the maximum product temperature is 650 K.
    """

    ####### OBJECTIVE IS TO MAXIMIZE H2 COMPOSITION IN PRODUCT STREAM #######
    m.fs.obj = pyo.Objective(
        expr=m.fs.product.mole_frac_comp[0, "H2"], sense=pyo.maximize
    )

    # MINIMUM PRODUCT FLOW OF 3500 mol/s IN PRODUCT STREAM
    @m.Constraint()
    def min_product_flow_mol(m):
        return m.fs.product.flow_mol[0] >= 3500

    # MAXIMUM N2 COMPOSITION OF 0.3 IN PRODUCT STREAM
    @m.Constraint()
    def max_product_N2_comp(m):
        return m.fs.product.mole_frac_comp[0, "N2"] <= 0.3

    # MAXIMUM REFORMER OUTLET TEMPERATURE OF 1200 K
    @m.Constraint()
    def max_reformer_outlet_temp(m):
        return m.fs.reformer_recuperator.hot_side_inlet.temperature[0] <= 1200

    # MAXIMUM PRODUCT OUTLET TEMPERATURE OF 650 K
    @m.Constraint()
    def max_product_temp(m):
        return m.fs.product.temperature[0] <= 650

    m.fs.feed.outlet.flow_mol[0].setlb(1120)
    m.fs.feed.outlet.flow_mol[0].setub(1250)

    # Unfix D.O.F. If you unfix these variables, inlet temperature, flow and composition
    # to the Gibbs reactor will have to be determined by the optimization problem.
    m.fs.reformer_bypass.split_fraction[0, "bypass_outlet"].unfix()
    m.fs.steam_feed.flow_mol.unfix()
    m.fs.feed.outlet.flow_mol.unfix()

    return m

df = {'X':[], 'P':[], 'Termination':[], 'Time':[], 'Objective':[], 'Steam':[], 'Bypass Frac': [], 'CH4 Feed':[]}

if __name__ == "__main__":

    for X in [0.90,0.91,0.92,0.93,0.94,0.95,0.96,0.97]:
        for P in np.arange(1447379,1947379,70000):
            m = pyo.ConcreteModel(name='NN_ATR_Flowsheet')
            m.fs = FlowsheetBlock(dynamic = False)
            
            build_nn_atr_flowsheet(m, conversion=X)
            set_nn_atr_flowsheet_inputs(m,P)
            initialize_nn_atr_flowsheet(m)
            m.fs.reformer_bypass.inlet.temperature.unfix()
            m.fs.reformer_bypass.inlet.flow_mol.unfix()
            make_optimization_model(m)
                
            ####### CONSTRAINTS #######

            # Link outputs of NN to inputs of reformer_recuperator 
            @m.Constraint()
            def link_T(m):
                return m.fs.reformer_recuperator.shell_inlet.flow_mol[0] == m.fs.reformer.out_flow_mol

            @m.Constraint()
            def link_F(m):
                return m.fs.reformer_recuperator.shell_inlet.temperature[0] == m.fs.reformer.out_temp

            @m.Constraint()
            def link_H2(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2'] == m.fs.reformer.out_H2

            @m.Constraint()
            def link_CO(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO'] == m.fs.reformer.out_CO

            @m.Constraint()
            def link_H2O(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'H2O'] == m.fs.reformer.out_H2O

            @m.Constraint()
            def link_CO2(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CO2'] == m.fs.reformer.out_CO2

            @m.Constraint()
            def link_CH4(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'CH4'] == m.fs.reformer.out_CH4

            @m.Constraint()
            def link_C2H6(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C2H6'] <= 3.46e-7

            @m.Constraint()
            def link_C3H8(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C3H8'] <= 2.27e-11

            @m.Constraint()
            def link_C4H10(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'C4H10'] <= 1.34e-15

            @m.Constraint()
            def link_N2(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'N2'] == m.fs.reformer.out_N2

            @m.Constraint()
            def link_O2(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'O2'] <= 1e-19

            @m.Constraint()
            def link_Ar(m):
                return m.fs.reformer_recuperator.shell_inlet.mole_frac_comp[0, 'Ar'] == m.fs.reformer.out_Ar
            
            solver = get_solver()
            solver.options = {
                "tol": 1e-7,
                "max_iter": 300
            }

            timer = TicTocTimer()
            timer.tic('starting timer')
            results = solver.solve(m, tee=True)
            dT = timer.toc('end')
            df[list(df.keys())[0]].append(X)
            df[list(df.keys())[1]].append(P)
            df[list(df.keys())[2]].append(results.solver.termination_condition)
            df[list(df.keys())[3]].append(dT)
            df[list(df.keys())[4]].append(value(m.fs.product.mole_frac_comp[0, 'H2']))
            df[list(df.keys())[5]].append(value(m.fs.steam_feed.flow_mol[0]))
            df[list(df.keys())[6]].append(value(m.fs.reformer_bypass.split_fraction[0, 'bypass_outlet']))
            df[list(df.keys())[7]].append(value(m.fs.feed.outlet.flow_mol[0]))
# Out:
# WARNING (W1002): Setting Var 'fs.steam_feed.properties[0.0].flow_mol' to a
# numeric value `464.77` outside the bounds (200.0522428, 349.8636404).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:34:54 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Starting initialization
# 2023-10-03 16:34:54 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:54 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Starting initialization
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.hot_side: Initialization Complete
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Starting initialization
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Starting initialization
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator.cold_side: Initialization Complete
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.reformer_recuperator: Initialization Completed, optimal - Optimal Solution Found
# 2023-10-03 16:34:55 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Starting initialization
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 16:34:56 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:57 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:58 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.intercooler_s1.control_volume: Initialization Complete
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.intercooler_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:34:59 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Starting initialization
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.air_compressor_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:00 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.intercooler_s2.control_volume: Initialization Complete
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.intercooler_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Starting initialization
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Property initialization: optimal - Optimal Solution Found.
# WARNING (W1002): Setting Var
# 'fs.reformer_bypass.reformer_outlet_state[0.0].flow_mol' to a numeric value
# `580.95` outside the bounds (601.206081, 899.7018541).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Starting initialization
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Starting initialization
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:01 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:02 [INFO] idaes.init.fs.reformer_bypass: Initialization Step 2 Complete: optimal - Optimal Solution Found
# [    0.00] starting timer
# Ipopt 3.13.2: tol=1e-07
# max_iter=300
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     5874
# Number of nonzeros in inequality constraint Jacobian.:        8
# Number of nonzeros in Lagrangian Hessian.............:     3563
#
# Total number of variables............................:     1046
#                      variables with only lower bounds:       26
#                 variables with lower and upper bounds:      966
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1039
# Total number of inequality constraints...............:        8
#         inequality constraints with only lower bounds:        1
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        7
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -9
-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80 -4.0275396e-01 9.90e-06 9.56e-07  -8.0 2.63e+02    -  1.00e+00 1.00e+00h  1
#   81 -4.0275394e-01 3.73e-08 2.26e-08  -8.0 1.20e+01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 81
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.0275393930679987e-01   -4.0275393930679987e-01
# Dual infeasibility......:   2.2600170190581723e-08    2.2600170190581723e-08
# Constraint violation....:   2.3283064365386963e-10    3.7252902984619141e-08
# Complementarity.........:   1.2470395650190582e-08    1.2470395650190582e-08
# Overall NLP error.......:   2.2600170190581723e-08    3.7252902984619141e-08
#
#
# Number of objective function evaluations             = 98
# Number of objective gradient evaluations             = 80
# Number of equality constraint evaluations            = 98
# Number of inequality constraint evaluations          = 98
# Number of equality constraint Jacobian evaluations   = 84
# Number of inequality constraint Jacobian evaluations = 84
# Number of Lagrangian Hessian evaluations             = 81
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.595
# Total CPU secs in NLP function evaluations           =      0.608
#
# EXIT: Optimal Solution Found.
# [+   1.93] end
# WARNING (W1002): Setting Var 'fs.steam_feed.properties[0.0].flow_mol' to a
# numeric value `464.77` outside the bounds (200.0522428, 349.8636404).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:35:05 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Starting initialization
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Starting initialization
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.hot_side: Initialization Complete
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Starting initialization
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Starting initialization
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:06 [INFO] idaes.init.fs.reformer_recuperator.cold_side: Initialization Complete
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.reformer_recuperator: Initialization Completed, optimal - Optimal Solution Found
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Starting initialization
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:07 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:08 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:09 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.intercooler_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.intercooler_s1.control_volume: Initialization Complete
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.intercooler_s1: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:10 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Starting initialization
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:11 [INFO] idaes.init.fs.air_compressor_s2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.air_compressor_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.intercooler_s2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.intercooler_s2.control_volume: Initialization Complete
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.intercooler_s2: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Starting initialization
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.reformer_bypass.mixed_state: Property initialization: optimal - Optimal Solution Found.
# WARNING (W1002): Setting Var
# 'fs.reformer_bypass.reformer_outlet_state[0.0].flow_mol' to a numeric value
# `580.95` outside the bounds (601.206081, 899.7018541).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:35:12 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Starting initialization
# 2023-10-03 16:35:13 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:13 [INFO] idaes.init.fs.reformer_bypass.reformer_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:13 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Starting initialization
# 2023-10-03 16:35:13 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:13 [INFO] idaes.init.fs.reformer_bypass.bypass_outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:13 [INFO] idaes.init.fs.reformer_bypass: Initialization Step 2 Complete: optimal - Optimal Solution Found
# [    0.00] starting timer
# Ipopt 3.13.2: tol=1e-07
# max_iter=300
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     5874
# Number of nonzeros in inequality constraint Jacobian.:        8
# Number of nonzeros in Lagrangian Hessian.............:     3563
#
# Total number of variables............................:     1046
#                      variables with only lower bounds:       26
#                 variables with lower and upper bounds:      966
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     
+01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 106
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.0406707082995502e-01   -4.0406707082995502e-01
# Dual infeasibility......:   2.2563084967466436e-08    2.2563084967466436e-08
# Constraint violation....:   2.3283064365386963e-10    2.9802322387695312e-08
# Complementarity.........:   1.2486627151195047e-08    1.2486627151195047e-08
# Overall NLP error.......:   2.2563084967466436e-08    2.9802322387695312e-08
#
#
# Number of objective function evaluations             = 198
# Number of objective gradient evaluations             = 102
# Number of equality constraint evaluations            = 198
# Number of inequality constraint evaluations          = 198
# Number of equality constraint Jacobian evaluations   = 110
# Number of inequality constraint Jacobian evaluations = 110
# Number of Lagrangian Hessian evaluations             = 106
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.993
# Total CPU secs in NLP function evaluations           =      0.870
#
# EXIT: Optimal Solution Found.
# [+   2.74] end
# WARNING (W1002): Setting Var 'fs.steam_feed.properties[0.0].flow_mol' to a
# numeric value `464.77` outside the bounds (200.0522428, 349.8636404).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Starting initialization
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Starting initialization
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.hot_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.hot_side: Initialization Complete
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Starting initialization
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Starting initialization
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.cold_side.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:18 [INFO] idaes.init.fs.reformer_recuperator.cold_side: Initialization Complete
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.reformer_recuperator: Initialization Completed, optimal - Optimal Solution Found
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Starting initialization
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.syngas_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Starting initialization
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.bypass_inlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Starting initialization
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:19 [INFO] idaes.init.fs.bypass_rejoin.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.bypass_rejoin: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.product.properties: Starting initialization
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.product.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.product.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.product: Initialization Complete.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.feed.properties: Starting initialization
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.feed.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.feed.properties: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.NG_expander.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:20 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.NG_expander.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Starting initialization
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.NG_expander.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.NG_expander: Initialization Complete: optimal - Optimal Solution Found
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Starting initialization
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:21 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Starting initialization
# 2023-10-03 16:35:22 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:22 [INFO] idaes.init.fs.air_compressor_s1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:22 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Starting initialization
# 2023-10-03 16:35:22 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:22 [INFO] idaes.init.fs.air_compressor_s1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-10-03 16:35:22 [INFO] idaes.init.fs.air_compressor_s1: Initialization Complete: optimal - Optimal Solution Found
# ...
#  137r-1.9309294e-01 1.68e+08 4.07e+02   1.0 1.64e+00   1.3 3.53e-01 5.63e-01f  1
#  138r-1.8732702e-01 1.66e+08 2.28e+02   1.0 2.49e+00   1.8 4.52e-01 5.82e-01h  1
#  139r-1.8320638e-01 1.76e+08 4.53e+01   1.0 7.34e-01   1.3 9.90e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140r-1
#  294r-2.1425188e-01 2.54e+08 4.08e+02  -2.7 2.91e+00  -0.4 3.32e-01 1.66e-02f  1
#  295r-2.1425456e-01 2.54e+08 1.37e+00  -2.7 4.46e-01  -0.0 1.00e+00 1.00e+00f  1
#  296r-2.1425580e-01 2.54e+08 3.00e+02  -2.7 1.27e+00  -0.5 5.64e-01 1.61e-01f  1
#  297r-2.1426160e-01 2.54e+08 1.83e+02  -2.7 6.99e+00  -1.0 1.23e-01 2.64e-01f  1
#  298r-2.1426694e-01 2.54e+08 3.32e+02  -2.7 1.71e+00  -0.5 3.04e-02 6.39e-01f  1
#  299r-2.1427158e-01 2.54e+08 5.92e+02  -2.7 3.10e+00  -1.0 8.97e-01 1.99e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300r-2.1430779e-01 2.54e+08 3.70e+02  -2.7 3.58e+00  -1.5 3.96e-01 5.97e-01f  1
#
# Number of Iterations....: 300
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -2.1430779067832048e-01   -2.1430779067832048e-01
# Dual infeasibility......:   1.8138162400370260e+02    1.8138162400370260e+02
# Constraint violation....:   1.8537088935106109e+01    2.5377842384854239e+08
# Complementarity.........:   2.7888943890015956e-02    2.7888943890015956e-02
# Overall NLP error.......:   1.7739394412583877e+02    2.5377842384854239e+08
#
#
# Number of objective function evaluations             = 398
# Number of objective gradient evaluations             = 120
# Number of equality constraint evaluations            = 398
# Number of inequality constraint evaluations          = 398
# Number of equality constraint Jacobian evaluations   = 313
# Number of inequality constraint Jacobian evaluations = 313
# Number of Lagrangian Hessian evaluations             = 300
# Total CPU secs in IPOPT (w/o function evaluations)   =      5.762
# Total CPU secs in NLP function evaluations           =      2.931
#
# EXIT: Maximum Number of Iterations Exceeded.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="NN_ATR_Flowsheet";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.13.2\x3a Maximum Number of Iterations
#       Exceeded.
# [+   9.62] end

# %%
pd.DataFrame(df)
# Out:
#        X        P    Termination       Time  Objective       Steam  \
# 0   0.90  1447379        optimal   1.929836   0.402754  275.623106
# 1   0.90  1517379        optimal   2.740551   0.404067  278.580643
# 2   0.90  1587379        optimal   2.169847   0.405299  281.422525
# 3   0.90  1657379  maxIterations  11.233812   0.387104  292.830155
# 4   0.90  1727379        optimal   2.295408   0.407553  286.815089
# ..   ...      ...            ...        ...        ...         ...
# 59  0.97  1657379  maxIterations  10.748386   0.320338  341.138435
# 60  0.97  1727379     infeasible   6.897281   0.348984  200.052272
# 61  0.97  1797379     infeasible   5.285919   0.347121  200.052243
# 62  0.97  1867379  maxIterations   8.468410   0.430202  349.491443
# 63  0.97  1937379  maxIterations   9.618818   0.214308  349.846507
#
#     Bypass Frac     CH4 Feed
# 0      0.375302  1249.999916
# 1      0.372645  1249.999916
# 2      0.370128  1249.999916
# 3      0.397084  1219.934099
# 4      0.365456  1249.999916
# ..          ...          ...
# 59     0.455965  1249.993174
# 60     0.501309  1250.000000
# 61     0.510706  1250.000000
# 62     0.374992  1249.991129
# 63     0.617863  1249.997118
#
# [64 rows x 8 columns]

# %%
df = pd.DataFrame(df)
df.to_csv("NETDATA.csv")
